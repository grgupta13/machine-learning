# %%
from lazypredict.Supervised import LazyClassifier
import pandas as pd
data = pd.read_csv("heart.csv")

y = data.pop('target').to_numpy() # this will return the target and remove it from data
X= data

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 11.29it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.84               0.84     0.84      0.84
# QuadraticDiscriminantAnalysis      0.82               0.82     0.82      0.82
# LabelPropagation                   0.79               0.79     0.79      0.79
# BernoulliNB                        0.79               0.79     0.79      0.79
# NearestCentroid                    0.79               0.79     0.79      0.79
# LabelSpreading                     0.79               0.79     0.79      0.79
# KNeighborsClassifier               0.79               0.79     0.79      0.79
# SGDClassifier                      0.79               0.79     0.79      0.79
# RandomForestClassifier             0.77               0.77     0.77      0.77
# NuSVC                              0.77               0.77     0.77      0.77
# BaggingClassifier                  0.77               0.77     0.77      0.77
# ExtraTreesClassifier               0.75               0.75     0.75      0.75
# RidgeClassifier                    0.75               0.75     0.75      0.75
# LinearDiscriminantAnalysis         0.75               0.75     0.75      0.75
# LogisticRegression                 0.75               0.75     0.75      0.75
# RidgeClassifierCV                  0.75               0.75     0.75      0.75
# CalibratedClassifierCV             0.75               0.75     0.75      0.75
# LinearSVC                          0.75               0.75     0.75      0.75
# SVC                                0.75               0.75     0.75      0.75
# ExtraTreeClassifier                0.74               0.74     0.74      0.74
# PassiveAggressiveClassifier        0.74               0.74     0.74      0.74
# AdaBoostClassifier                 0.74               0.74     0.74      0.74
# DecisionTreeClassifier             0.74               0.74     0.74      0.74
# LGBMClassifier                     0.72               0.72     0.72      0.72
# XGBClassifier                      0.70               0.70     0.70      0.70
# Perceptron                         0.57               0.57     0.57      0.57
# DummyClassifier                    0.51               0.50     0.50      0.34
#
#                                Time Taken
# Model
# GaussianNB                           0.03
# QuadraticDiscriminantAnalysis        0.03
# LabelPropagation                     0.03
# BernoulliNB                          0.03
# NearestCentroid                      0.04
# LabelSpreading                       0.05
# KNeighborsClassifier                 0.04
# SGDClassifier                        0.04
# RandomForestClassifier               0.42
# NuSVC                                0.04
# BaggingClassifier                    0.08
# ExtraTreesClassifier                 0.41
# RidgeClassifier                      0.02
# LinearDiscriminantAnalysis           0.03
# LogisticRegression                   0.04
# RidgeClassifierCV                    0.03
# CalibratedClassifierCV               0.14
# LinearSVC                            0.04
# SVC                                  0.04
# ExtraTreeClassifier                  0.05
# PassiveAggressiveClassifier          0.04
# AdaBoostClassifier                   0.41
# DecisionTreeClassifier               0.07
# LGBMClassifier                       0.12
# XGBClassifier                        0.14
# Perceptron                           0.04
# DummyClassifier                      0.06

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.84               0.84     0.84      0.84
# QuadraticDiscriminantAnalysis      0.82               0.82     0.82      0.82
# LabelPropagation                   0.79               0.79     0.79      0.79
# BernoulliNB                        0.79               0.79     0.79      0.79
# NearestCentroid                    0.79               0.79     0.79      0.79
# LabelSpreading                     0.79               0.79     0.79      0.79
# KNeighborsClassifier               0.79               0.79     0.79      0.79
# SGDClassifier                      0.79               0.79     0.79      0.79
# RandomForestClassifier             0.77               0.77     0.77      0.77
# NuSVC                              0.77               0.77     0.77      0.77
# BaggingClassifier                  0.77               0.77     0.77      0.77
# ExtraTreesClassifier               0.75               0.75     0.75      0.75
# RidgeClassifier                    0.75               0.75     0.75      0.75
# LinearDiscriminantAnalysis         0.75               0.75     0.75      0.75
# LogisticRegression                 0.75               0.75     0.75      0.75
# RidgeClassifierCV                  0.75               0.75     0.75      0.75
# CalibratedClassifierCV             0.75               0.75     0.75      0.75
# LinearSVC                          0.75               0.75     0.75      0.75
# SVC                                0.75               0.75     0.75      0.75
# ExtraTreeClassifier                0.74               0.74     0.74      0.74
# PassiveAggressiveClassifier        0.74               0.74     0.74      0.74
# AdaBoostClassifier                 0.74               0.74     0.74      0.74
# DecisionTreeClassifier             0.74               0.74     0.74      0.74
# LGBMClassifier                     0.72               0.72     0.72      0.72
# XGBClassifier                      0.70               0.70     0.70      0.70
# Perceptron                         0.57               0.57     0.57      0.57
# DummyClassifier                    0.51               0.50     0.50      0.34
#
#                                Time Taken
# Model
# GaussianNB                           0.03
# QuadraticDiscriminantAnalysis        0.03
# LabelPropagation                     0.03
# BernoulliNB                          0.03
# NearestCentroid                      0.04
# LabelSpreading                       0.05
# KNeighborsClassifier                 0.04
# SGDClassifier                        0.04
# RandomForestClassifier               0.42
# NuSVC                                0.04
# BaggingClassifier                    0.08
# ExtraTreesClassifier                 0.41
# RidgeClassifier                      0.02
# LinearDiscriminantAnalysis           0.03
# LogisticRegression                   0.04
# RidgeClassifierCV                    0.03
# CalibratedClassifierCV               0.14
# LinearSVC                            0.04
# SVC                                  0.04
# ExtraTreeClassifier                  0.05
# PassiveAggressiveClassifier          0.04
# AdaBoostClassifier                   0.41
# DecisionTreeClassifier               0.07
# LGBMClassifier                       0.12
# XGBClassifier                        0.14
# Perceptron                           0.04
# DummyClassifier                      0.06

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np
from sklearn.model_selection import train_test_split

boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state=13)
X = X.astype(np.float32)

X_train,X_test, y_train, y_test = train_test_split(X,y,train_size = 0.7, random_state = 14)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 42/42 [00:10<00:00,  3.90it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.89       0.90  3.07        0.29
# RandomForestRegressor                        0.88       0.89  3.29        0.64
# XGBRegressor                                 0.87       0.88  3.42        0.29
# BaggingRegressor                             0.86       0.87  3.51        0.11
# HistGradientBoostingRegressor                0.86       0.87  3.54        0.86
# LGBMRegressor                                0.85       0.87  3.58        0.16
# ExtraTreesRegressor                          0.84       0.85  3.74        0.53
# AdaBoostRegressor                            0.82       0.83  4.00        0.40
# DecisionTreeRegressor                        0.77       0.79  4.48        0.03
# PoissonRegressor                             0.71       0.74  5.03        0.04
# ExtraTreeRegressor                           0.70       0.73  5.11        0.02
# TransformedTargetRegressor                   0.68       0.70  5.34        0.02
# LinearRegression                             0.68       0.70  5.34        0.02
# LassoCV                                      0.68       0.70  5.35        0.14
# Ridge                                        0.68       0.70  5.35        0.03
# RidgeCV                                      0.68       0.70  5.35        0.04
# LassoLarsCV                                  0.68       0.70  5.35        0.06
# LassoLarsIC                                  0.67       0.70  5.36        0.02
# SGDRegressor                                 0.67       0.70  5.37        0.05
# BayesianRidge                                0.67       0.70  5.37        0.02
# ElasticNetCV                                 0.67       0.70  5.37        0.17
# HuberRegressor                               0.66       0.69  5.47        0.05
# LarsCV                                       0.65       0.68  5.56        0.05
# LinearSVR                                    0.65       0.68  5.56        0.02
# OrthogonalMatchingPursuitCV                  0.64       0.67  5.66        0.05
# RANSACRegressor                              0.61       0.64  5.87        0.39
# Lars                                         0.59       0.62  6.01        0.02
# Lasso                                        0.59       0.62  6.04        0.02
# MLPRegressor                                 0.58       0.62  6.05        0.77
# KNeighborsRegressor                          0.56       0.59  6.25        0.04
# ElasticNet                                   0.54       0.58  6.39        0.02
# TweedieRegressor                             0.52       0.56  6.52        0.03
# GammaRegressor                               0.52       0.56  6.53        0.03
# SVR                                          0.48       0.53  6.74        0.06
# NuSVR                                        0.47       0.52  6.82        0.03
# OrthogonalMatchingPursuit                    0.47       0.52  6.83        0.02
# PassiveAggressiveRegressor                   0.46       0.51  6.88        0.02
# GaussianProcessRegressor                     0.15       0.22  8.66        0.06
# DummyRegressor                              -0.12      -0.03  9.95        0.02
# LassoLars                                   -0.12      -0.03  9.95        0.02
# QuantileRegressor                           -0.19      -0.09 10.23        5.03
# KernelRidge                                 -5.03      -4.51 23.05        0.03

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.89       0.90  3.07        0.29
# RandomForestRegressor                        0.88       0.89  3.29        0.64
# XGBRegressor                                 0.87       0.88  3.42        0.29
# BaggingRegressor                             0.86       0.87  3.51        0.11
# HistGradientBoostingRegressor                0.86       0.87  3.54        0.86
# LGBMRegressor                                0.85       0.87  3.58        0.16
# ExtraTreesRegressor                          0.84       0.85  3.74        0.53
# AdaBoostRegressor                            0.82       0.83  4.00        0.40
# DecisionTreeRegressor                        0.77       0.79  4.48        0.03
# PoissonRegressor                             0.71       0.74  5.03        0.04
# ExtraTreeRegressor                           0.70       0.73  5.11        0.02
# TransformedTargetRegressor                   0.68       0.70  5.34        0.02
# LinearRegression                             0.68       0.70  5.34        0.02
# LassoCV                                      0.68       0.70  5.35        0.14
# Ridge                                        0.68       0.70  5.35        0.03
# RidgeCV                                      0.68       0.70  5.35        0.04
# LassoLarsCV                                  0.68       0.70  5.35        0.06
# LassoLarsIC                                  0.67       0.70  5.36        0.02
# SGDRegressor                                 0.67       0.70  5.37        0.05
# BayesianRidge                                0.67       0.70  5.37        0.02
# ElasticNetCV                                 0.67       0.70  5.37        0.17
# HuberRegressor                               0.66       0.69  5.47        0.05
# LarsCV                                       0.65       0.68  5.56        0.05
# LinearSVR                                    0.65       0.68  5.56        0.02
# OrthogonalMatchingPursuitCV                  0.64       0.67  5.66        0.05
# RANSACRegressor                              0.61       0.64  5.87        0.39
# Lars                                         0.59       0.62  6.01        0.02
# Lasso                                        0.59       0.62  6.04        0.02
# MLPRegressor                                 0.58       0.62  6.05        0.77
# KNeighborsRegressor                          0.56       0.59  6.25        0.04
# ElasticNet                                   0.54       0.58  6.39        0.02
# TweedieRegressor                             0.52       0.56  6.52        0.03
# GammaRegressor                               0.52       0.56  6.53        0.03
# SVR                                          0.48       0.53  6.74        0.06
# NuSVR                                        0.47       0.52  6.82        0.03
# OrthogonalMatchingPursuit                    0.47       0.52  6.83        0.02
# PassiveAggressiveRegressor                   0.46       0.51  6.88        0.02
# GaussianProcessRegressor                     0.15       0.22  8.66        0.06
# DummyRegressor                              -0.12      -0.03  9.95        0.02
# LassoLars                                   -0.12      -0.03  9.95        0.02
# QuantileRegressor                           -0.19      -0.09 10.23        5.03
# KernelRidge                                 -5.03      -4.51 23.05        0.03

# %%
cli.sys.getprofile()
